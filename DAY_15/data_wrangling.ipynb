# %% [markdown]
# # Data Wrangling
#
# Data wrangling is the process of `cleaning`, `transforming`, and `organizing` data so that it can be used for `analysis and visualization.` It is an important step inthe data analysis process because raw data is often `incomplete, inconsistent`, and in an `unstructured format`, which can make it difficult to work with.
#
#     Data wrangling helps to make the data more `consistent, accurate`, and `useful` for analysis and decision -making.

# %% [markdown]
# ## Step
#
# 1. Gathering Data
# 2. Tools to clean data
# 3. How to do,

# %%
#import "../../../../../../
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.isnull().sum() / len(df) * 100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
df.drop(columns="deck", inplace=True)

# %%
df['age'] = df['age'].astype(float)  # Convert to float
df['age'] = df['age'].fillna(df['age'].mean())  # Fill NaN values
df['age'] = df['age'].astype('category')  # Convert back to categorical if needed sass
# df['age'] = df.age.fillna(value = df['age'].mean())

# %%
df.isnull().sum() / len(df) * 100
# df = df.fillna(value =df['age'].mean())
# Out:
# survived       0.000000
# pclass         0.000000
# sex            0.000000
# age            0.000000
# sibsp          0.000000
# parch          0.000000
# fare           0.000000
# embarked       0.224467
# class          0.000000
# who            0.000000
# adult_male     0.000000
# embark_town    0.224467
# alive          0.000000
# alone          0.000000
# dtype: float64

# %%
# df['embarked'] = df['embarked'].astype(float)  # Convert to float
df['embarked'] = df['embarked'].fillna(df['embarked'].mode()[0])  # Fill NaN values
df['embarked'] = df['embarked'].astype('category')  # Convert back to categorical if needed sass

# %%
df['embark_town'] = df['embark_town'].fillna(df['embark_town'].mode()[0])  # Fill NaN values
df['embark_town'] = df['embark_town'].astype('category')  # Convert back to categorical if needed sass

# %% [markdown]
# # Outliers Remover
# Visualization Method

# %%
import seaborn as sns
sns.boxplot(data= df, y='age' ,x ='sex' , hue='sex')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
df.isnull().sum() / len(df) * 100
# Out:
# survived       0.0
# pclass         0.0
# sex            0.0
# age            0.0
# sibsp          0.0
# parch          0.0
# fare           0.0
# embarked       0.0
# class          0.0
# who            0.0
# adult_male     0.0
# embark_town    0.0
# alive          0.0
# alone          0.0
# dtype: float64

# %%
df
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male  embark_town alive  alone
# ...

# %%
#IQR method
# Q1 = df['age'].quantile(0.25)
# Q3 = df['age'].quantile(0.75)
# IQR = Q3- Q1
# IQR
# Ensure 'age' is numeric
df['age'] = pd.to_numeric(df['age'], errors='coerce')

# Compute IQR
Q1 = df['age'].quantile(0.25)
Q3 = df['age'].quantile(0.75)
IQR = Q3 - Q1
IQR
# Out:
# np.float64(13.0)

# %%
Q1 = df['age'].quantile(0.25)
Q3 = df['age'].quantile(0.75)
IQR = Q3 - Q1
IQR
# Compute the lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Remove outliers
df = df[(df['age'] >= lower_bound) & (df['age'] <= upper_bound)]

# %%
Q1 = df['fare'].quantile(0.25)
Q3 = df['fare'].quantile(0.75)
IQR = Q3 - Q1
IQR
# Compute the lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Remove outliers
df = df[(df['fare'] >= lower_bound) & (df['fare'] <= upper_bound)]

# %%
df.shape
# Out:
# (718, 14)

# %%
sns.histplot(df['fare'])
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
from scipy import stats
import numpy as np

zscore = np.abs(stats.zscore(df['age']))  # Compute Z-score
threshold = 3  # Set threshold for outliers
df = df[zscore < threshold]  # Keep only values within threshold

# %%
sns.histplot(df['age'])
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# # Finding and dropping duplicates

# %%
df.shape
# Out:
# (718, 14)

# %%
df.duplicated().sum()
# Out:
# np.int64(103)

# %%
df_duplicate =df[df.duplicated()]
df_duplicate.head()
# Out:
#     survived  pclass     sex        age  sibsp  parch    fare embarked  class  \
# 47         1       3  female  29.699118      0      0  7.7500        Q  Third
# 76         0       3    male  29.699118      0      0  7.8958        S  Third
# 77         0       3    male  29.699118      0      0  8.0500        S  Third
# 87         0       3    male  29.699118      0      0  8.0500        S  Third
# 95         0       3    male  29.699118      0      0  8.0500        S  Third
#
#       who  adult_male  embark_town alive  alone
# 47  woman       False   Queenstown   yes   True
# 76    man        True  Southampton    no   True
# 77    man        True  Southampton    no   True
# 87    man        True  Southampton    no   True
# 95    man        True  Southampton    no   True

# %%
#finding duplicates
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (615, 14)

# %% [markdown]
# # Data Noemalization

# %%
#1. import libraries
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
#2.data
df
#3.select columns to normalize
cols_to_normalize = ['age','fare']
#4.create the scaler  function/tool
scaler = MinMaxScaler()
#5.fit and transform the data on scaler or vice versa 
df[cols_to_normalize] = scaler.fit_transform(df[cols_to_normalize])
#6check the data 
df
# Out:
#      survived  pclass     sex       age  sibsp  parch      fare embarked  \
# 0           0       3    male  0.372549      1      0  0.118118        S
# 2           1       3  female  0.450980      0      0  0.129115        S
# 3           1       1  female  0.627451      1      0  0.865114        S
# 4           0       3    male  0.627451      0      0  0.131152        S
# 5           0       3    male  0.523512      0      0  0.137804        Q
# ..        ...     ...     ...       ...    ...    ...       ...      ...
# 885         0       3  female  0.705882      0      5  0.474509        Q
# 887         1       1  female  0.313725      0      0  0.488765        S
# 888         0       3  female  0.523512      1      2  0.382051        S
# 889         1       1    male  0.450980      0      0  0.488765        C
# 890         0       3    male  0.568627      0      0  0.126264        Q
#
#      class    who  adult_male  embark_town alive  alone
# ...

# %%
#log tranformation

#1. import libraries
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
#2.data
df
#3.select columns to normalize
cols_to_normalize = ['age','fare']
#4.create the scaler  function/tool
scaler = MinMaxScaler()
#5.fit and transform the data on scaler or vice versa 
df[cols_to_normalize] = scaler.fit_transform(df[cols_to_normalize])
#6check the data 
df
# Out:
#      survived  pclass     sex       age  sibsp  parch      fare embarked  \
# 0           0       3    male  0.372549      1      0  0.118118        S
# 2           1       3  female  0.450980      0      0  0.129115        S
# 3           1       1  female  0.627451      1      0  0.865114        S
# 4           0       3    male  0.627451      0      0  0.131152        S
# 5           0       3    male  0.523512      0      0  0.137804        Q
# ..        ...     ...     ...       ...    ...    ...       ...      ...
# 885         0       3  female  0.705882      0      5  0.474509        Q
# 887         1       1  female  0.313725      0      0  0.488765        S
# 888         0       3  female  0.523512      1      2  0.382051        S
# 889         1       1    male  0.450980      0      0  0.488765        C
# 890         0       3    male  0.568627      0      0  0.126264        Q
#
#      class    who  adult_male  embark_town alive  alone
# ...

# %%
kashti = sns.load_dataset("titanic")
kashti.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
kashti.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
import numpy as np

kashti['age'] = kashti['age'].fillna(kashti['age'].median())
kashti['fare'] = kashti['fare'].fillna(kashti['fare'].mean())

#log transform

kashti['age'] = np.log(kashti['age'])
kashti['fare'] = np.log(kashti['fare'])

kashti.head()
# Out:
# c:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#    survived  pclass     sex       age  sibsp  parch      fare embarked  class  \
# 0         0       3    male  3.091042      1      0  1.981001        S  Third
# 1         1       1  female  3.637586      1      0  4.266662        C  First
# 2         1       3  female  3.258097      0      0  2.070022        S  Third
# 3         1       1  female  3.555348      1      0  3.972177        S  First
# 4         0       3    male  3.555348      0      0  2.085672        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# ...

# %%
sns.boxplot(data=kashti, x="sex", y="fare")
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
sns.histplot(kashti["age"])
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone'],
#       dtype='object')

# %%
df["family_size"] = df["sibsp"]+df["parch"]

# %%
sns.swarmplot(data=df, x='sex', y="age", hue="family_size")
# Out:
# c:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 6.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='sex', ylabel='age'>
# c:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 12.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 6.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
df = df.rename(columns={'survived':'survival'})
df.columns
# Out:
# Index(['survival', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone', 'family_size'],
#       dtype='object')

# %%
table = pd.pivot_table(df,values='age', index='pclass' ,columns = "survival" ,aggfunc=np.sum)
table
# Out:
# C:\Program Files\KMSpico\temp\ipykernel_17868\2510761380.py:1: FutureWarning: The provided callable <function sum at 0x00000219FE4A0220> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   table = pd.pivot_table(df,values='age', index='pclass' ,columns = "survival" ,aggfunc=np.sum)
# survival           0          1
# pclass
# 1          25.958616  32.874371
# 2          40.694083  33.574441
# 3         133.977618  38.934931

# %%
sns.scatterplot(data=df, x='fare', y='age')
# Out:
# <Axes: xlabel='fare', ylabel='age'>

# %%
df["family_size"] = df["sibsp"]+df["parch"]

# %%
df.head()
# Out:
#    survival  pclass     sex       age  sibsp  parch      fare embarked  class  \
# 0         0       3    male  0.372549      1      0  0.118118        S  Third
# 2         1       3  female  0.450980      0      0  0.129115        S  Third
# 3         1       1  female  0.627451      1      0  0.865114        S  First
# 4         0       3    male  0.627451      0      0  0.131152        S  Third
# 5         0       3    male  0.523512      0      0  0.137804        Q  Third
#
#      who  adult_male  embark_town alive  alone  family_size
# 0    man        True  Southampton    no  False            1
# 2  woman       False  Southampton   yes   True            0
# 3  woman       False  Southampton   yes  False            1
# 4    man        True  Southampton    no   True            0
# 5    man        True   Queenstown    no   True            0

# %%
df.to_csv("preprocessed_data.csv")
